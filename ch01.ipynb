# %% [markdown]
# # 第1章: 準備運動

# %% [markdown]
# ## 00. パタトクカシーー
# 2つの文字列「パトカー」と「タクシー」の文字を先頭から交互に連結し、文字列「パタトクカシーー」を得よ。

# %%
p = "パトカー"
t = "タクシー"

ans = ""
for x,y in zip(p,t):
  ans += x + y

print(ans)
# Out:
# パタトクカシーー

# %% [markdown]
# ## 01. タクシー
# 文字列「パタトクカシーー」の2, 4, 6, 8文字目を取り出し、それらを連結した文字列を得よ。

# %%
s = "パタトクカシーー"

ans = ""
for i,x in enumerate(s,1):
  if i%2 == 0:
    ans += x

print(ans)
# Out:
# タクシー

# %% [markdown]
# ## 02. 文字列の逆順
# 文字列"stressed"の文字を逆に（末尾から先頭に向かって）並べた文字列を得よ。

# %%
s = "stressed"
l_s = list(s)
l_s.reverse()
print("".join(l_s))
# Out:
# desserts

# %% [markdown]
# ## 03. 円周率
# "Now I need a drink, alcoholic of course, after the heavy lectures involving quantum mechanics."という文を単語に分解し、各単語の（アルファベットの）文字数を先頭から出現順に並べたリストを作成せよ。

# %%
s = "Now I need a drink, alcoholic of course, after the heavy lectures involving quantum mechanics."

words = s.replace(",","").replace(".","").split()
anw = [len(word) for word in words]
print(ans)
# Out:
# [3, 1, 4, 1, 5, 9, 2, 6, 5, 3, 5, 8, 9, 7, 9]

# %% [markdown]
# ## 04. 元素記号
# "Hi He Lied Because Boron Could Not Oxidize Fluorine. New Nations Might Also Sign Peace Security Clause. Arthur King Can."という文を単語に分解し、1, 5, 6, 7, 8, 9, 15, 16, 19番目の単語は先頭の1文字、それ以外の単語は先頭の2文字を取り出し、取り出した文字列から単語の位置（先頭から何番目の単語か）への連想配列（辞書型もしくはマップ型）を作成せよ。

# %%
s = "Hi He Lied Because Boron Could Not Oxidize Fluorine. New Nations Might Also Sign Peace Security Clause. Arthur King Can."
pos = [1, 5, 6, 7, 8, 9, 15, 16, 19]

words = s.replace(".","").split()

ans = []
for i,word in enumerate(words,1):
  if i in pos:
    ans.append(word[:1])
  else:
    ans.append(word[:2])

print(ans)
# Out:
# ['H', 'He', 'Li', 'Be', 'B', 'C', 'N', 'O', 'F', 'Ne', 'Na', 'Mi', 'Al', 'Si', 'P', 'S', 'Cl', 'Ar', 'K', 'Ca']

# %% [markdown]
# ## 05. n-gram
# 与えられたシーケンス（文字列やリストなど）からn-gramを作る関数を作成せよ。この関数を用い、"I am an NLPer"という文から文字tri-gram、単語bi-gramを得よ。

# %%
def ngram(seq, n):
    ret = []
    for i in range(len(seq) - n + 1):
        ret.append(seq[i:i+n])
    return ret

s = "I am an NLPer"

char_tri = ngram(s, 3)
word_bi = ngram(s.split(), 2)

print(char_tri)
print(word_bi)
# Out:
# ['I a', ' am', 'am ', 'm a', ' an', 'an ', 'n N', ' NL', 'NLP', 'LPe', 'Per']
# [['I', 'am'], ['am', 'an'], ['an', 'NLPer']]

# %% [markdown]
# ## 06. 集合
# "paraparaparadise"と"paragraph"に含まれる文字bi-gramの集合を、それぞれ, $X$ と $Y$ として求め、$X$ と $Y$ の和集合（$X \cup Y$）、積集合（$X \cap Y$）、差集合（$X \setminus Y$）を求めよ。さらに、'se'というbi-gramがXおよびYに含まれるかどうかを調べよ。

# %%
X = set(ngram("paraparaparadise", 2))
Y = set(ngram("paragraph", 2))

print(f"X = {X}")
print(f"Y = {Y}")
print(f"X | Y = {X | Y}")
print(f"X & Y = {X & Y}")
print(f"X - Y = {X - Y}")
# Out:
# X = {'ad', 'di', 'ra', 'ap', 'se', 'pa', 'ar', 'is'}
# Y = {'gr', 'ph', 'ra', 'ap', 'pa', 'ar', 'ag'}
# X | Y = {'ad', 'gr', 'di', 'ph', 'ra', 'ap', 'se', 'pa', 'ar', 'ag', 'is'}
# X & Y = {'ap', 'pa', 'ra', 'ar'}
# X - Y = {'di', 'ad', 'se', 'is'}

# %% [markdown]
# ## 07. テンプレートによる文生成
# 引数x, y, zを受け取り「x時のyはz」という文字列を返す関数を実装せよ。さらに、x=12, y="気温", z=22.4として、実行結果を確認せよ。

# %%
def makeString(x,y,z):
  return f"{x}時の{y}は{z}"

print(makeString(12,"気温",22.4))
# Out:
# 12時の気温は22.4

# %% [markdown]
# ## 08. 暗号文
# 与えられた文字列の各文字を、以下の仕様で変換する関数cipherを実装せよ。
#
# * 英小文字ならば (219 - 文字コード) のASCIIコードに対応する文字に置換
# * その他の文字はそのまま出力
#
# この関数を用い、英語のメッセージを暗号化・復号化せよ。

# %%
def cipher(s):
  ret = ""
  for x in s:
    if x.islower() and x.isalpha():
      ret += chr(219-ord(x))
    else:
      ret += x
  return ret

encryption = cipher("100LanguageProcessingExercises")
decryption = cipher(encryption)
print(f"暗号化 : 100LanguageProcessingExercises → {encryption}")
print(f"復号化 : {encryption} → {decryption}")
# Out:
# 暗号化 : 100LanguageProcessingExercises → 100LzmtfztvPilxvhhrmtEcvixrhvh
# 復号化 : 100LzmtfztvPilxvhhrmtEcvixrhvh → 100LanguageProcessingExercises

# %% [markdown]
# ## 09. Typoglycemia
# スペースで区切られた単語列に対して、各単語の先頭と末尾の文字は残し、それ以外の文字の順序をランダムに並び替えるプログラムを作成せよ。ただし、長さが４以下の単語は並び替えないこととする。適当な英語の文（例えば"I couldn't believe that I could actually understand what I was reading : the phenomenal power of the human mind ."）を与え、その実行結果を確認せよ。

# %%
import random

s = "I couldn't believe that I could actually understand what I was reading : the phenomenal power of the human mind ."
words = s.split()

ans = []
for x in words:
  if len(x) <= 4:
    ans.append(x)
  else:
    middle = list(x[1:-1])
    random.shuffle(middle)
    ans.append(x[0] + "".join(middle) + x[-1])

print(' '.join(ans))
# Out:
# I clndu'ot bvileee that I cuold altcualy uarndntsed what I was rdnieag : the pnoeenmhal pewor of the haumn mind .
